# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
pip install langchain_openai
# Out:
# Requirement already satisfied: langchain_openai in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (1.1.7)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.6 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain_openai) (1.2.9)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain_openai) (0.12.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain_openai) (2.17.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (9.1.4)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.6.9)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (4.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.13.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (0.28.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.12.1)
# Requirement already satisfied: tqdm>4 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain_openai) (4.67.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.32.5)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain_openai) (2026.1.15)
# Requirement already satisfied: idna>=2.8 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain_openai) (3.11)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=1.109.1->langchain_openai) (1.3.1)
# Requirement already satisfied: certifi in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=1.109.1->langchain_openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.6->langchain_openai) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (1.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (3.11.7)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.25.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.6->langchain_openai) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain_openai) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.6->langchain_openai) (2.41.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain_openai) (3.4.4)
# Requirement already satisfied: colorama in c:\users\hanjo\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain_openai) (0.4.6)
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: c:\Users\hanjo\.pyenv\pyenv-win\versions\3.10.11\python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()

# %%
llm.invoke("인프런에 어떤 강의가 있나요?")
# Out:
# AIMessage(content='인프런에는 다양한 주제의 수백 개의 강의가 있습니다. 주요 카테고리로는 프로그래밍, 디자인, 비즈니스, 마케팅, 언어학습, 취미 등이 있으며, 각 카테고리 안에도 세부적인 주제로 나뉘어져 있습니다. 예를 들어 프로그래밍 카테고리 안에는 파이썬, 자바스크립트, 리액트, 머신러닝 등 다양한 주제의 강의가 제공됩니다. 인프런에서는 강사들이 직접 제작한 고퀄리티의 강의를 만나볼 수 있으며, 강의 수강 후에는 즉시 인증서를 발급받을 수도 있습니다. 원하는 분야의 강의를 검색하여 자신에게 맞는 강의를 찾아 수강해 보세요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 274, 'prompt_tokens': 26, 'total_tokens': 300, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D6yQAzGZVGNIAi3R697VaIUPkhpFw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c3d47-203c-7d12-8890-fa8e8bac576e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 274, 'total_tokens': 300, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
